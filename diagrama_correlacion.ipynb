# %% [markdown]
# *EDA Y ETL DEL MODELO

# %%
#importar bibliotecas necesarias 
import pandas as pd
import numpy as np

# %%
# Cargar el dataset
data = pd.read_csv('movies_clean.csv', low_memory= False)

# %%
data
# Out:
#                 belongs_to_collection      budget                      genres  \
# 0                toy story collection  30000000.0   animation, comedy, family
# 1                     sin informacion  65000000.0  adventure, fantasy, family
# 2           grumpy old men collection         0.0             romance, comedy
# 3                     sin informacion  16000000.0      comedy, drama, romance
# 4      father of the bride collection         0.0                      comedy
# ...                               ...         ...                         ...
# 45446                 sin informacion         0.0      drama, action, romance
# 45447                 sin informacion         0.0                       drama
# 45448                 sin informacion         0.0     action, drama, thriller
# 45449                 sin informacion         0.0                         NaN
# 45450                 sin informacion         0.0                         NaN
#
#            id original_language  \
# 0         862                en
# 1        8844                en
# 2       15602                en
# 3       31357                en
# 4       11862                en
# ...       ...               ...
# 45446   30840                en
# 45447  111109                tl
# 45448   67758                en
# 45449  227506                en
# 45450  461257                en
#
#                                                 overview  popularity  \
# 0      led by woody, andy's toys live happily in his ...   21.946943
# 1      when siblings judy and peter discover an encha...   17.015539
# 2      a family wedding reignites the ancient feud be...   11.712900
# 3      cheated on, mistreated and stepped on, the wom...    3.859495
# 4      just when george banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 45446  yet another version of the classic epic, with ...    5.683753
# 45447  an artist struggles to finish his work while a...    0.178241
# 45448  when one of her hits goes wrong, a professiona...    0.903007
# 45449  in a small town live two brothers, one a minis...    0.003503
# 45450  50 years after decriminalisation of homosexual...    0.163015
#
#                                     production_companies  \
# 0                                pixar animation studios
# 1      tristar pictures, teitler film, interscope com...
# 2                           warner bros., lancaster gate
# 3                 twentieth century fox film corporation
# 4             sandollar productions, touchstone pictures
# ...                                                  ...
# 45446  westdeutscher rundfunk (wdr), working title fi...
# 45447                                        sine olivia
# 45448                            american world pictures
# 45449                                          yermoliev
# 45450                                                NaN
#
#                                     production_countries release_date  ...  \
# 0                               united states of america   1995-10-30  ...
# 1                               united states of america   1995-12-15  ...
# 2                               united states of america   1995-12-22  ...
# 3                               united states of america   1995-12-22  ...
# 4                               united states of america   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45446  canada, germany, united kingdom, united states...   1991-05-13  ...
# 45447                                        philippines   2011-11-17  ...
# 45448                           united states of america   2003-08-01  ...
# 45449                                             russia   1917-10-21  ...
# 45450                                     united kingdom   2017-06-09  ...
#
#                              title  vote_average vote_count  \
# 0                        toy story           7.7     5415.0
# 1                          jumanji           6.9     2413.0
# 2                 grumpier old men           6.5       92.0
# 3                waiting to exhale           6.1       34.0
# 4      father of the bride part ii           5.7      173.0
# ...                            ...           ...        ...
# 45446                   robin hood           5.7       26.0
# 45447          century of birthing           9.0        3.0
# 45448                     betrayal           3.8        6.0
# 45449             satan triumphant           0.0        0.0
# 45450                     queerama           0.0        0.0
#
#                                                     cast          director  \
# 0      tom hanks, tim allen, don rickles, jim varney,...     john lasseter
# 1      robin williams, jonathan hyde, kirsten dunst, ...      joe johnston
# 2      walter matthau, jack lemmon, ann-margret, soph...     howard deutch
# 3      whitney houston, angela bassett, loretta devin...   forest whitaker
# 4      steve martin, diane keaton, martin short, kimb...     charles shyer
# ...                                                  ...               ...
# 45446  patrick bergin, uma thurman, david morrissey, ...        john irvin
# 45447  angel aquino, perry dizon, hazel orencio, joel...          lav diaz
# 45448  erika eleniak, adam baldwin, julie du page, ja...    mark l. lester
# 45449  iwan mosschuchin, nathalie lissenko, pavel pav...  yakov protazanov
# 45450                                                NaN     daisy asquith
#
#        release_year  release_month release_day     return        earns
# 0              1995             10          30  12.451801  343554033.0
# 1              1995             12          15   4.043035  197797249.0
# 2              1995             12          22   0.000000          0.0
# 3              1995             12          22   5.090760   65452156.0
# 4              1995              2          10   0.000000   76578911.0
# ...             ...            ...         ...        ...          ...
# 45446          1991              5          13   0.000000          0.0
# 45447          2011             11          17   0.000000          0.0
# 45448          2003              8           1   0.000000          0.0
# 45449          1917             10          21   0.000000          0.0
# 45450          2017              6           9   0.000000          0.0
#
# [45451 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45451 entries, 0 to 45450
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  45451 non-null  object
#  1   budget                 45451 non-null  float64
#  2   genres                 43067 non-null  object
#  3   id                     45451 non-null  int64
#  4   original_language      45451 non-null  object
#  5   overview               45451 non-null  object
#  6   popularity             45451 non-null  float64
#  7   production_companies   33634 non-null  object
#  8   production_countries   39232 non-null  object
#  9   release_date           45451 non-null  object
#  10  revenue                45451 non-null  float64
#  11  runtime                45451 non-null  float64
#  12  spoken_languages       45230 non-null  object
#  13  status                 45451 non-null  object
#  14  title                  45451 non-null  object
#  15  vote_average           45451 non-null  float64
#  16  vote_count             45451 non-null  float64
#  17  cast                   43097 non-null  object
#  18  director               45451 non-null  object
#  19  release_year           45451 non-null  int64
#  20  release_month          45451 non-null  int64
#  21  release_day            45451 non-null  int64
#  22  return                 45451 non-null  float64
#  23  earns                  45451 non-null  float64
# dtypes: float64(8), int64(4), object(12)
# memory usage: 8.3+ MB

# %%
data.drop('id',axis = "columns",inplace = True)
data.drop('overview',axis = "columns",inplace = True)
data.drop('budget',axis = "columns",inplace = True)
data.drop('revenue',axis = "columns",inplace = True)
data.drop('production_countries',axis = "columns",inplace = True)
data.drop('spoken_languages',axis = "columns",inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45451 entries, 0 to 45450
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  45451 non-null  object
#  1   genres                 43067 non-null  object
#  2   original_language      45451 non-null  object
#  3   popularity             45451 non-null  float64
#  4   production_companies   33634 non-null  object
#  5   release_date           45451 non-null  object
#  6   runtime                45451 non-null  float64
#  7   status                 45451 non-null  object
#  8   title                  45451 non-null  object
#  9   vote_average           45451 non-null  float64
#  10  vote_count             45451 non-null  float64
#  11  cast                   43097 non-null  object
#  12  director               45451 non-null  object
#  13  release_year           45451 non-null  int64
#  14  release_month          45451 non-null  int64
#  15  release_day            45451 non-null  int64
#  16  return                 45451 non-null  float64
#  17  earns                  45451 non-null  float64
# dtypes: float64(6), int64(3), object(9)
# memory usage: 6.2+ MB

# %%
data['release_date'] = pd.to_datetime(data['release_date'])

# %% [markdown]
# #A continuacion e realiza una categorizacion de valores numericos a variables cuantitativos

# %%
data['popularity'] = pd.qcut(data['popularity'],q = 5, labels=['Desconocida','Conocida', 'Popular','Muy Popular','Obra Maestra'])
data['vote_average'] = pd.qcut(data['vote_average'],q = 4, labels=['Mala','Buena','Muy Buena','Excelente'])
data['runtime'] = pd.qcut(data['runtime'],q = 3, labels=['Poca Duracion', 'Media Duracion', 'Larga Duracion'])
data['release_date'] = (data['release_date'].dt.year//10)*10

# %% [markdown]
# #*Ahora se convierten todas las columnas a variables categoricas representadas en numeros

# %%
data['belongs_to_collection'] = pd.Categorical(data['belongs_to_collection']).codes
data['genres'] = pd.Categorical(data['genres']).codes
data['original_language'] = pd.Categorical(data['original_language']).codes
data['production_companies'] = pd.Categorical(data['production_companies']).codes
data['status'] = pd.Categorical(data['status']).codes
data['popularity'] = pd.Categorical(data['popularity']).codes
data['vote_average'] = pd.Categorical(data['vote_average']).codes
data['release_date'] = pd.Categorical(data['release_date']).codes
data['runtime'] = pd.Categorical(data['runtime']).codes

# %% [markdown]
# #* Se hace el diagrama de correlacion para verificar la redundancia de los datos

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /var/folders/cf/5nv863qj24s_gxr8p3cmtljr0000gn/T/ipykernel_2382/1398619703.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <style type="text/css">
# #T_c4236_row0_col0, #T_c4236_row1_col1, #T_c4236_row2_col2, #T_c4236_row3_col3, #T_c4236_row4_col4, #T_c4236_row5_col5, #T_c4236_row6_col6, #T_c4236_row7_col7, #T_c4236_row8_col8, #T_c4236_row9_col9, #T_c4236_row10_col10, #T_c4236_row11_col11, #T_c4236_row12_col12, #T_c4236_row13_col13, #T_c4236_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c4236_row0_col1, #T_c4236_row0_col2, #T_c4236_row3_col11, #T_c4236_row12_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_c4236_row0_col3, #T_c4236_row0_col9, #T_c4236_row0_col11, #T_c4236_row0_col12, #T_c4236_row0_col14, #T_c4236_row1_col8, #T_c4236_row3_col0, #T_c4236_row3_col2, #T_c4236_row3_col7, #T_c4236_row4_col5, #T_c4236_row4_col10, #T_c4236_row5_col4, #T_c4236_row5_col8, #T_c4236_row5_col11, #T_c4236_row5_col13, #T_c4236_row6_col13, #T_c4236_row7_col6, #T_c4236_row7_col11, #T_c4236_row7_col12, #T_c4236_row10_col4, #T_c4236_row10_col8, #T_c4236_row10_col11, #T_c4236_row10_col13, #T_c4236_row12_col13, #T_c4236_row14_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c4236_row0_col4, #T_c4236_row4_col1, #T_c4236_row5_col6, #T_c4236_row8_col0, #T_c4236_row10_col6, #T_c4236_row13_col3 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c4236_row0_col5, #T_c4236_row0_col10, #T_c4236_row7_col10 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_c4236_row0_col6, #T_c4236_row2_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c4236_row0_col7, #T_c4236_row1_col2, #T_c4236_row4_col0, #T_c4236_row6_col12, #T_c4236_row8_col11, #T_c4236_row11_col8, #T_c4236_row12_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c4236_row0_col8, #T_c4236_row2_col3, #T_c4236_row2_col11, #T_c4236_row4_col7, #T_c4236_row9_col2, #T_c4236_row13_col8 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c4236_row0_col13, #T_c4236_row2_col9, #T_c4236_row2_col13, #T_c4236_row7_col13, #T_c4236_row11_col13, #T_c4236_row14_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_c4236_row1_col0, #T_c4236_row1_col5, #T_c4236_row1_col10, #T_c4236_row13_col5, #T_c4236_row13_col10 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c4236_row1_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c4236_row1_col4, #T_c4236_row14_col5, #T_c4236_row14_col10 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_c4236_row1_col6, #T_c4236_row6_col7, #T_c4236_row12_col7, #T_c4236_row12_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c4236_row1_col7, #T_c4236_row1_col12, #T_c4236_row8_col1, #T_c4236_row14_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c4236_row1_col9, #T_c4236_row1_col14, #T_c4236_row5_col7, #T_c4236_row5_col12, #T_c4236_row10_col7, #T_c4236_row10_col12 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c4236_row1_col11, #T_c4236_row7_col3, #T_c4236_row8_col7, #T_c4236_row9_col7, #T_c4236_row9_col11, #T_c4236_row9_col12, #T_c4236_row13_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_c4236_row1_col13, #T_c4236_row7_col8, #T_c4236_row8_col13, #T_c4236_row9_col1, #T_c4236_row9_col13, #T_c4236_row13_col6, #T_c4236_row13_col12 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c4236_row2_col0, #T_c4236_row2_col6, #T_c4236_row2_col8, #T_c4236_row12_col14, #T_c4236_row13_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c4236_row2_col4, #T_c4236_row10_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_c4236_row2_col5, #T_c4236_row2_col10, #T_c4236_row12_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_c4236_row2_col7, #T_c4236_row7_col9, #T_c4236_row12_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_c4236_row2_col12, #T_c4236_row3_col13, #T_c4236_row4_col13 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c4236_row2_col14, #T_c4236_row9_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c4236_row3_col1, #T_c4236_row3_col12, #T_c4236_row7_col2, #T_c4236_row11_col0, #T_c4236_row11_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_c4236_row3_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_c4236_row3_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_c4236_row3_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_c4236_row3_col8, #T_c4236_row6_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_c4236_row3_col9 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_c4236_row3_col10 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_c4236_row3_col14 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_c4236_row4_col2, #T_c4236_row6_col1, #T_c4236_row7_col14, #T_c4236_row11_col1, #T_c4236_row13_col9 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c4236_row4_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c4236_row4_col6, #T_c4236_row14_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c4236_row4_col8, #T_c4236_row11_col9, #T_c4236_row11_col14, #T_c4236_row12_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c4236_row4_col9 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_c4236_row4_col11 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c4236_row4_col12, #T_c4236_row13_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_c4236_row4_col14, #T_c4236_row5_col9, #T_c4236_row8_col2, #T_c4236_row8_col14, #T_c4236_row9_col6, #T_c4236_row10_col9, #T_c4236_row11_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_c4236_row5_col0, #T_c4236_row6_col11, #T_c4236_row10_col0, #T_c4236_row13_col2, #T_c4236_row13_col14 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c4236_row5_col1, #T_c4236_row8_col12, #T_c4236_row10_col1, #T_c4236_row11_col7, #T_c4236_row14_col2, #T_c4236_row14_col11, #T_c4236_row14_col12 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c4236_row5_col2, #T_c4236_row7_col5, #T_c4236_row10_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c4236_row5_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_c4236_row5_col10, #T_c4236_row10_col5 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_c4236_row5_col14, #T_c4236_row11_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c4236_row6_col0, #T_c4236_row7_col0, #T_c4236_row7_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_c4236_row6_col2, #T_c4236_row12_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_c4236_row6_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_c4236_row6_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_c4236_row6_col8 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_c4236_row6_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_c4236_row6_col10, #T_c4236_row14_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_c4236_row6_col14 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_c4236_row7_col1, #T_c4236_row13_col11 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c4236_row8_col3 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_c4236_row8_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c4236_row8_col5, #T_c4236_row8_col10, #T_c4236_row11_col10 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_c4236_row8_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_c4236_row8_col9 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_c4236_row9_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_c4236_row9_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_c4236_row9_col5, #T_c4236_row9_col10 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c4236_row9_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c4236_row9_col14 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_c4236_row10_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_c4236_row11_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_c4236_row11_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c4236_row11_col12, #T_c4236_row12_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_c4236_row12_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_c4236_row12_col5, #T_

# %%
data.head()
# Out:
#    belongs_to_collection  genres  original_language  popularity  \
# 0                   1547    1078                 17           4
# 1                   1119     942                 17           4
# 2                    530    3293                 17           4
# 3                   1119    1387                 17           3
# 4                    435    1228                 17           4
#
#    production_companies  release_date  runtime  status  \
# 0                 15290            12        0       4
# 1                 19772            12        2       4
# 2                 21779            12        1       4
# 3                 19893            12        2       4
# 4                 16878            12        2       4
#
#                          title  vote_average  vote_count  \
# 0                    toy story             3      5415.0
# 1                      jumanji             3      2413.0
# 2             grumpier old men             2        92.0
# 3            waiting to exhale             2        34.0
# 4  father of the bride part ii             1       173.0
#
#                                                 cast         director  \
# 0  tom hanks, tim allen, don rickles, jim varney,...    john lasseter
# 1  robin williams, jonathan hyde, kirsten dunst, ...     joe johnston
# 2  walter matthau, jack lemmon, ann-margret, soph...    howard deutch
# 3  whitney houston, angela bassett, loretta devin...  forest whitaker
# 4  steve martin, diane keaton, martin short, kimb...    charles shyer
#
#    release_year  release_month  release_day     return        earns
# 0          1995             10           30  12.451801  343554033.0
# 1          1995             12           15   4.043035  197797249.0
# 2          1995             12           22   0.000000          0.0
# 3          1995             12           22   5.090760   65452156.0
# 4          1995              2           10   0.000000   76578911.0

# %%
data.to_csv('data_ML.csv', index=False)
